# %%
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots

import matplotlib.pyplot as plt

import seaborn as sns

from matplotlib.ticker import FuncFormatter

# %%
file_path = "C:\\Users\\ozgeu\\Desktop\\Kodlasam\\Capstone\\Spotify_Youtube.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0       Artist  \
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 20713  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                 Track                           Album  \
# 20713            JUST DANCE HARDSTYLE            JUST DANCE HARDSTYLE
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SET FIRE TO THE RAIN HARDSTYLE
# 20715       OUTSIDE HARDSTYLE SPED UP       OUTSIDE HARDSTYLE SPED UP
# 20716             ONLY GIRL HARDSTYLE             ONLY GIRL HARDSTYLE
# 20717              MISS YOU HARDSTYLE              MISS YOU HARDSTYLE
#
# ...

# %%
url_cols = ['Unnamed: 0', 'Url_spotify', 'Uri', 'Url_youtube', 'Title', 'Description']
df.drop(url_cols, axis=1, inplace=True)

# %%
df.head()
# Out:
#      Artist                                          Track  \
# 0  Gorillaz                                 Feel Good Inc.
# 1  Gorillaz                                Rhinestone Eyes
# 2  Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3  Gorillaz                             On Melancholy Hill
# 4  Gorillaz                                 Clint Eastwood
#
#                                            Album Album_type  Danceability  \
# 0                                     Demon Days      album         0.818
# 1                                  Plastic Beach      album         0.676
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single         0.695
# 3                                  Plastic Beach      album         0.689
# 4                                       Gorillaz      album         0.663
#
#    Energy   Key  Loudness  Speechiness  Acousticness  ...  Valence    Tempo  \
# 0   0.705   6.0    -6.679       0.1770      0.008360  ...    0.772  138.559
# ...

# %%
df.columns
# Out:
# Index(['Artist', 'Track', 'Album', 'Album_type', 'Danceability', 'Energy',
#        'Key', 'Loudness', 'Speechiness', 'Acousticness', 'Instrumentalness',
#        'Liveness', 'Valence', 'Tempo', 'Duration_ms', 'Channel', 'Views',
#        'Likes', 'Comments', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19549 entries, 0 to 20717
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            19549 non-null  object
#  1   Track             19549 non-null  object
#  2   Album             19549 non-null  object
#  3   Album_type        19549 non-null  object
#  4   Danceability      19549 non-null  float64
#  5   Energy            19549 non-null  float64
#  6   Key               19549 non-null  float64
#  7   Loudness          19549 non-null  float64
#  8   Speechiness       19549 non-null  float64
#  9   Acousticness      19549 non-null  float64
#  10  Instrumentalness  19549 non-null  float64
#  11  Liveness          19549 non-null  float64
#  12  Valence           19549 non-null  float64
#  13  Tempo             19549 non-null  float64
#  14  Duration_ms       19549 non-null  float64
#  15  Channel           19549 non-null  object
# ...

# %%
df.describe()
# Out:
#        Danceability        Energy           Key      Loudness   Speechiness  \
# count  19549.000000  19549.000000  19549.000000  19549.000000  19549.000000
# mean       0.621059      0.635170      5.294337     -7.633179      0.095392
# std        0.165489      0.213555      3.579338      4.618839      0.106243
# min        0.000000      0.000020      0.000000    -46.251000      0.000000
# 25%        0.519000      0.508000      2.000000     -8.772000      0.035700
# 50%        0.639000      0.666000      5.000000     -6.516000      0.050700
# 75%        0.742000      0.797000      8.000000     -4.929000      0.104000
# max        0.975000      1.000000     11.000000      0.920000      0.964000
#
#        Acousticness  Instrumentalness      Liveness       Valence  \
# count  19549.000000      19549.000000  19549.000000  19549.000000
# mean       0.289106          0.055292      0.191226      0.528950
# std        0.285908          0.192519      0.165197      0.245228
# ...

# %%
df.shape
# Out:
# (19549, 22)

# %%
df.nunique()
# Out:
# Artist               2040
# Track               16866
# Album               11381
# Album_type              3
# Danceability          895
# Energy               1254
# Key                    12
# Loudness             9095
# Speechiness          1263
# Acousticness         3094
# Instrumentalness     3915
# Liveness             1517
# Valence              1283
# Tempo               14308
# Duration_ms         14005
# Channel              6482
# Views               18613
# Likes               17494
# Comments            10310
# Licensed                2
# official_video          2
# Stream              17964
# dtype: int64

# %% [markdown]
# # Boş değerleri kontrol edelim:

# %%
df.isna().sum()
# Out:
# Artist              0
# Track               0
# Album               0
# Album_type          0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_ms         0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Licensed            0
# official_video      0
# Stream              0
# dtype: int64

# %%
df[df['Tempo'].isna()]
# Out:
# Empty DataFrame
# Columns: [Artist, Track, Album, Album_type, Danceability, Energy, Key, Loudness, Speechiness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_ms, Channel, Views, Likes, Comments, Licensed, official_video, Stream]
# Index: []
#
# [0 rows x 22 columns]

# %%
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.show()

# %% [markdown]
# # Data Type' ları inceledim:

# %%
print(df.dtypes)
# Out:
# Artist               object
# Track                object
# Album                object
# Album_type           object
# Danceability        float64
# Energy              float64
# Key                 float64
# Loudness            float64
# Speechiness         float64
# Acousticness        float64
# Instrumentalness    float64
# Liveness            float64
# Valence             float64
# Tempo               float64
# Duration_ms         float64
# Channel              object
# Views               float64
# Likes               float64
# Comments            float64
# Licensed             object
# official_video       object
# Stream              float64
# dtype: object

# %%
df.describe()
# Out:
#        Danceability        Energy           Key      Loudness   Speechiness  \
# count  19549.000000  19549.000000  19549.000000  19549.000000  19549.000000
# mean       0.621059      0.635170      5.294337     -7.633179      0.095392
# std        0.165489      0.213555      3.579338      4.618839      0.106243
# min        0.000000      0.000020      0.000000    -46.251000      0.000000
# 25%        0.519000      0.508000      2.000000     -8.772000      0.035700
# 50%        0.639000      0.666000      5.000000     -6.516000      0.050700
# 75%        0.742000      0.797000      8.000000     -4.929000      0.104000
# max        0.975000      1.000000     11.000000      0.920000      0.964000
#
#        Acousticness  Instrumentalness      Liveness       Valence  \
# count  19549.000000      19549.000000  19549.000000  19549.000000
# mean       0.289106          0.055292      0.191226      0.528950
# std        0.285908          0.192519      0.165197      0.245228
# ...

# %%
album_type_count = df['Album_type'].value_counts()
print(album_type_count)
# Out:
# Album_type
# album          14148
# single          4689
# compilation      712
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=album_type_count.index, y=album_type_count.values, palette='viridis')

plt.title('Count of Each Album Type')
plt.xlabel('Album Type')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.show()

# %%
# Assuming 'top_10' is the DataFrame containing the top 10 artists
top_10 = artist_sorted.head(10)

# Reset index for easier plotting
top_10 = top_10.reset_index()

# Plotting
plt.figure(figsize=(14, 8))

# Create a grouped bar plot
top_10_melted = top_10.melt(id_vars='Artist', value_vars=['Views', 'Stream'], var_name='Platform', value_name='Count')

sns.barplot(data=top_10_melted, x='Artist', y='Count', hue='Platform', palette='viridis')

plt.title('Top 10 Artists by YouTube Views and Spotify Streams')
plt.xlabel('Artist')
plt.ylabel('Count (Billions)')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 # Assuming 'top_10' is the DataFrame containing the top 10 artists
# ----> 2 top_10 = artist_sorted.head(10)
#       4 # Reset index for easier plotting
#       5 top_10 = top_10.reset_index()
#
# NameError: name 'artist_sorted' is not defined

# %%
# Function to format numbers in billions
def formatter(x, pos):
    return f'{x * 1e-9:.1f}B'

# Sorting the data
ed_sheeran = ed_sheeran.sort_values('TotalListened', ascending=False)

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(data=ed_sheeran, x='TotalListened', y='Track', ax=ax)

# Setting formatter for the x-axis
ax.xaxis.set_major_formatter(FuncFormatter(formatter))

# Setting labels and title
ax.set_xlabel("Total listened on both platforms (Billions)")
ax.set_ylabel("Track")
ax.set_title("Most popular tracks by Ed Sheeran", fontsize=20)

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 6
#       3     return f'{x * 1e-9:.1f}B'
#       5 # Sorting the data
# ----> 6 ed_sheeran = ed_sheeran.sort_values('TotalListened', ascending=False)
#       8 # Plotting
#       9 fig, ax = plt.subplots(figsize=(10, 6))
#
# NameError: name 'ed_sheeran' is not defined

# %%
# Top 10 songs based on views
top10_views = df.nlargest(10, 'Views')

# Top 10 songs based on comments
top10_comments = df.nlargest(10, 'Comments')

# Top 10 songs based on likes
top10_likes = df.nlargest(10, 'Likes')

# %%
# Create a figure with 3 subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(24, 8))

# Top 10 songs based on views
sns.barplot(data=top10_views, x='Views', y='Track', ax=axes[0], palette='Blues_d')
axes[0].set_title('Top 10 Songs by YouTube Views')
axes[0].set_xlabel('Views')
axes[0].set_ylabel('Track')

# Top 10 songs based on comments
sns.barplot(data=top10_comments, x='Comments', y='Track', ax=axes[1], palette='Greens_d')
axes[1].set_title('Top 10 Songs by YouTube Comments')
axes[1].set_xlabel('Comments')
axes[1].set_ylabel('Track')

# Top 10 songs based on likes
sns.barplot(data=top10_likes, x='Likes', y='Track', ax=axes[2], palette='Oranges_d')
axes[2].set_title('Top 10 Songs by YouTube Likes')
axes[2].set_xlabel('Likes')
axes[2].set_ylabel('Track')

# Adjust layout for better spacing
plt.tight_layout()

# Display the plots
plt.show()
# Out:
# C:\Users\ozgeu\AppData\Local\Temp\ipykernel_8636\1601420608.py:23: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   plt.tight_layout()
# C:\Users\ozgeu\AppData\Local\Temp\ipykernel_8636\1601420608.py:23: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   plt.tight_layout()
# C:\Users\ozgeu\AppData\Local\Temp\ipykernel_8636\1601420608.py:23: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   plt.tight_layout()
# C:\Users\ozgeu\AppData\Local\Temp\ipykernel_8636\1601420608.py:23: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   plt.tight_layout()
# C:\Users\ozgeu\AppData\Local\Temp\ipykernel_8636\1601420608.py:23: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.tight_layout()
# ...

# %%
# Data preparation
top_songs = df.sort_values('Stream', ascending=False).head(10)
top_songs_features = top_songs[['Track', 'Energy', 'Danceability', 'Acousticness']]

# Radar chart preparation
categories = ['Energy', 'Danceability', 'Acousticness']
N = len(categories)

# Create a radar chart for each track
fig, axes = plt.subplots(nrows=2, ncols=5, subplot_kw=dict(polar=True), figsize=(20, 10))
fig.suptitle("Top 10 Songs: Energy, Danceability, and Acousticness", fontsize=16)

# Plot each song in a separate radar chart
for i, (index, row) in enumerate(top_songs_features.iterrows()):
    values = row[categories].values.flatten().tolist()
    values += values[:1]  # Repeat the first value to close the loop
    
    angles = [n / float(N) * 2 * np.pi for n in range(N)]
    angles += angles[:1]

    ax = axes.flatten()[i]
    ax.set_title(row['Track'], size=10, color='black', y=1.1)
    
    ax.plot(angles, values, linewidth=2, linestyle='solid')
    ax.fill(angles, values, alpha=0.4)

    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(categories)
    
    ax.set_yticklabels([])  # Remove y-axis labels for clarity

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.95])

# Show the plot
plt.show()

# %% [markdown]
# # Songs with dance beats are more popular

# %%
danceability_track = df.groupby(['Track','Danceability']).sum().reset_index()
danceability_track = danceability_track[danceability_track['Danceability'] > 0.9]\
.sort_values('Views',ascending=False).head(10)

fig = sns.barplot(danceability_track,y='Track',x='Views')
fig.set_title("Most popular video with high of danceability on Youtube",fontsize=15)
fig.xaxis.set_major_formatter(formatter)
fig.set_xlabel("Total views in Billions")
# Out:
# Text(0.5, 0, 'Total views in Billions')

# %%
from matplotlib.ticker import FuncFormatter, NullFormatter

# Define the formatter to convert numbers to billions
def formatter(x, pos):
    return f'{x * 1e-9:.1f}B'

# Create subplots
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(30, 10))
fig.subplots_adjust(wspace=0.5)

# Valence with score above 0.8
happy_track = df.groupby(['Track', 'Valence']).sum().sort_values('Stream', ascending=False).reset_index()
happy_track = happy_track[happy_track['Valence'] > 0.8].head(10)

sns.barplot(data=happy_track, x='Stream', y='Track', ax=ax1, palette='viridis')
ax1.set_title("Most Viewed Tracks with Happy Vibes", fontsize=20)
ax1.xaxis.set_major_formatter(FuncFormatter(formatter))
ax1.xaxis.set_minor_formatter(NullFormatter())
ax1.set_xlabel("Stream in Billion")

# Valence with score below 0.2
sad_track = df.groupby(['Track', 'Valence']).sum().sort_values('Stream', ascending=False).reset_index()
sad_track = sad_track[sad_track['Valence'] < 0.2].head(10)

sns.barplot(data=sad_track, x='Stream', y='Track', ax=ax2, palette='coolwarm')
ax2.set_title("Most Viewed Tracks with Sad Vibes", fontsize=20)
ax2.xaxis.set_major_formatter(FuncFormatter(formatter))
ax2.xaxis.set_minor_formatter(NullFormatter())
ax2.set_xlabel("Stream in Billion")

# Set the main title for the figure
fig.suptitle("Most Viewed Tracks Based on Happy and Sad Vibes", fontsize=30)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure the 'Comments' column is numeric
df['Comments'] = pd.to_numeric(df['Comments'], errors='coerce')

# Sort the DataFrame by the number of comments in descending order
top_comments = df.sort_values(by='Comments', ascending=False).head(10)

# Plotting
plt.figure(figsize=(12, 8))
sns.barplot(data=top_comments, x='Comments', y='Track', palette='viridis')
plt.title('Top 10 Tracks with Most Comments on YouTube', fontsize=16)
plt.xlabel('Number of Comments')
plt.ylabel('Track')
plt.xscale('log')  # Optional: log scale for better visualization if there's a large range

plt.show()
# Out:
# C:\Users\ozgeu\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ozgeu\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ozgeu\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ozgeu\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ozgeu\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data = df[['Views', 'Likes']].dropna()  # Drop rows with missing values

# Scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Views', y='Likes', alpha=0.5)
plt.title('Relationship Between Views and Likes on YouTube Videos', fontsize=16)
plt.xlabel('Views')
plt.ylabel('Likes')

# Calculate and display correlation coefficient
correlation = np.corrcoef(data['Views'], data['Likes'])[0, 1]
plt.figtext(0.15, 0.85, f'Correlation: {correlation:.2f}', fontsize=12, color='red')

plt.xscale('log')  # Optional: log scale for better visualization if data spans several orders of magnitude
plt.yscale('log')  # Optional: log scale for better visualization

plt.show()

# %%
# Sort the DataFrame by the stream count in descending order
top_streams = df.sort_values(by='Stream', ascending=False).head(10)

# Plotting
plt.figure(figsize=(12, 8))
sns.barplot(data=top_streams, x='Stream', y='Track', palette='coolwarm')
plt.title('Top 10 Songs by Stream Count', fontsize=16)
plt.xlabel('Stream Count')
plt.ylabel('Track')
plt.xscale('log')  # Optional: log scale for better visualization if there's a large range

plt.show()
